# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
webpage=requests.get('https://www.libertybooks.com/categories/non-fiction/books-on-religion-and-spirituality/islam').text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!-- LiteSpeed Cache created with user_agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36-->
# <!DOCTYPE html>
# <!--[if IE]><![endif]-->
# <!--[if IE 8 ]>
# <html dir="ltr" lang="en" class="ie8"><![endif]-->
# <!--[if IE 9 ]>
# <html dir="ltr" lang="en" class="ie9"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html dir="ltr" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Islam
#   </title>
#   <base href="https://www.libertybooks.com/"/>
#   <meta content="Islam" name="description"/>
#   <link href="catalog/view/theme/liberty/stylesheet/optimized.css" rel="stylesheet"/>
#   <link href="catalog/view/theme/liberty/stylesheet/megamenu-v1-1.css" rel="stylesheet"/>
# ...

# %%
soup.find_all('h2',class_='page-title my-category-title')[0].text
# Out:
# 'Islam'

# %% [markdown]
# ### TO FIND OUT NAMES OF THE Categories

# %%
for i in soup.find_all('prodcut_items'):
  print(i.text.strip())

# %%
soup.find_all('h4','a').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 soup.find_all('h4','a').text
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\bs4\element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
len(soup.find_all('h2',class_='page-title my-category-title'))

# %%
for book in books:
    # Extract the book title
    title = book.find('h4', 'a').text.strip() if book.find('h4','a') else 'Title not available'
    print("Title is:", {title})

# %%
print(books)
# Out:
# []
